# %% [markdown]
# Churn in banking, also known as customer attrition, is when a customer closes their accounts, stops using a bank's services, or moves their money
# to a competitor (another Bank)

# %% [markdown]
# ### Use Cases in Banking Industry :
# - `Churn Models` : These Models are built using Data Science techniques to identify Customers who have high chances of Churn
# (churn : One bank to another , Churn affects the business )
# - `Cross Sell Models` : These Models are built to identify Customers who have high propensity to another schemes in Bank who already have
# - existing schemes
# - `Forecasting Models` : These Models are built to Forecast Saving Rates , Renewal Rates
# - `Lead Generations Models` : These Models arev buit to Forecast to generate Schemes like Personal Loan , Auto Loan
# - `Regulatory Models` : These Models are built on RBI regulatory Guidelines, like IFRS Models

# %% [markdown]
# There are two types of Customers in the Banking Sector
# - Asset and Liability
# - 1.`Liability Customers` : Liability customers are those who deposit the money in the Bank, So they are the Liability
# to the Bank, because Bank has to give them the Interest on the Money which they deposited
# - In Indian Banking Systems we have : Saving Deposits , Current Deposits and we have Fixed Deposits
# - 2.`Asset Customers` : Asset customers are the ones who take Loans from the Bank
# - Loans can be of various categories - Home Loans , Business loans , MSME loan (micro, small, and medium enterprises) and also for Large Corporates -
# Which are the big Assets or high valued customers of the Bank
# - How Bank works is , it takes the Interest from the ones whom it is lending the money
# - So, Churn is important for both , neither Asset nor Liability Customers should leave
# - If it starts losing its Savings Bank customers , the Deposits which the Bank gets , example : If i have a Salary account and the
# Salary doesn't go to the Account , then the Bank will not have that much money and it will not be able to lend money to other customers
# - This is the reason it is very important for the Banks to Identify and Stop these Churns

# %% [markdown]
# ### Two types of Churn

# %% [markdown]
# Soft Churn and Hard Churn  (These two, use the Churn Models)
# - Hard Churn : You suddenly close your account in just 2 or 3 months
# - Soft churn : You close your account within s due course of time
# In such case , the indication is - The Balance amount in the Account  keeps decreasing , becuase he starts
# withdrawing the amount slowly and finally its completely empty

# %% [markdown]
# ### Cross-Sell Model
# A cross-sell bank model is a data-driven strategy and predictive framework used by financial institutions to offer additional financial products or services to existing customers. Because acquiring a new customer is up to five times more expensive than selling to an existing one, banks rely heavily on these models to increase profitability, boost customer retention, and maximize the "share of wallet"
# - Suppose I have a Savings Account in SBI , when they realise I am maintaining good Balance and I am a Potential Customer , they will
# - try to sell me a Term Loan
# Why Banks Offer Term Loans
# - `Interest Income:` Banks earn a profit by charging interest (fixed or variable) on the principal amount borrowed over the life of the loan.
# - `Relationship Building:` Providing financing helps banks build long-term relationships with businesses and consumers, leading to cross-selling opportunities for other financial products like checking accounts, treasury services, or insurance.
# The messages that you get about Home Loan, Auto Loan etc are the strategies of cross-sell only, because the bank knows you are not a defaulter
# - So, they will try to sell more schemes Example : If you are having a Home Loan , they will sell you Personal Loan
# - which is charged at a very high Interest

# %% [markdown]
# ### Forecasting Model

# %% [markdown]
# Banks run forecast data models to predict future cash flows, manage financial risks, and move from reactive reporting to proactive decision-makin
# #### Key Reasons Banks Use Forecast Models
# - `Risk Management:` Models help institutions predict interest rate shifts, assess real-time credit risk, and evaluate
# borrower health based on current cash flows
# - `Liquidity and Cash Flow Control:` By tracking Bank Data Forecasting insights, banks can accurately anticipate deposit flows,
# avoid shortfalls, and ensure enough cash is available to meet daily demands.
# - `Fraud Prevention and Security:` Predictive models analyze customer behavioral patterns to spot and block
# fraudulent transactions before they happen
# - `Strategic Planning:` Executives use Financial Forecasting tools to align loan portfolios with market demand,
# plan budgets, and optimize capital allocation
# - `Operational Efficiency:` Forecasts help manage branch staffing, streamline ATM cash logistics, and prepare digital systems for peak usage

# %% [markdown]
# #### Forecasting Models are important to know what is the Savings Rate (the rate at which savings accounts are being created)
# - How many people are closing their Savings Accounts
# - The Rate at which the Balance is increasing on Daily basis
# - Ideally the Savings balance should not fall
# - 0 to 3% is the Minimum ideal increase percentage in Savings bank as per Indian Banks Standard
# - If a Bank has Ten Thousand Crore savings Account Balance today , then Tomorrow it is likely to become TenThousand 100 Crores
# - It can decrease also
# - Determine the Savings Outflow Rate that how much money or treasury the Bank should maintain
# - A savings outflow rate (or deposit run-off rate) is the percentage of a bank’s deposits that customers are expected to withdraw or move out over a specific stress period
# - Run-off Rate: Another name for the outflow rate, showing how fast deposits "roll off" or leave the bank.
# ![image.png](attachment:6c9dfc32-b790-478a-8415-81d2e657b179.png)

# %% [markdown]
# #### Similarly we have the Forecasting for Renewal Rate :
# A renewal rate in banking typically refers to the new interest rate applied to a loan (like a mortgage) or a deposit product (like a certificate of deposit or term deposit) when its initial fixed term expires and is extended
# - Example :Suppose if a person is doing a Term Deposit , the renewal dat is after 1 year
# - And he has selected the option of Auto-renewing a Fixed Deposit
# - If you are renewing it , that means you are re-investing that money
# - And the Bank wants to know how many of their customers are renewing their Fixed Deposits
# - Generally it is 70 - 80 % but again , Bank wants to know this number . so that they can have an idea how much money they can lend to other
# customers

# %% [markdown]
# #### Forecasting can also be done for the Loan Customers

# %% [markdown]
# - Example : For MSME Customers , how many people will take Loan in future
# - Percentage of People taking loan

# %% [markdown]
# ### Lead Generation Model

# %% [markdown]
# Lead Generation Model uses SQL as well as Python
# - To get a segment of Customers who are eligible for a particular scheme
# - Like for Personal Loan or Auto Loan etc
# - This is determined on the bases of the minimum Salary a person is maintaining
# - a list of around 50 K to 1 Lakh Customers is generated
# - Since the customers being targeted is reasonable , the conversion rate becomes very high
# - In marketing, a conversion rate is the percentage of users or visitors who complete a
# desired action (example , A Scheme) out of the total number of people who visited a site or viewed an ad

# %% [markdown]
# Lead generation is the process of attracting and capturing potential customer interest and contact information to turn them into paying clients
# - these Lead Generations will be beneficial to the Bank in increasing the Business

# %% [markdown]
# ### Regulatory Models

# %% [markdown]
# Regulatory Models are something that are bult on RBI Guidelines
# - A regulatory bank model is a framework set by authorities to govern how financial institutions measure risks, hold capital, and comply with legal standards to ensure economic stability.
# - An IFRS bank model primarily revolves around IFRS 9 Financial Instruments, which dictates how financial institutions
# classify, measure, and provision for assets based on business models and credit ris
# - In this for example , Bank wants to know how much money they are Risking in the next year
# - How many defaulters will be there

# %% [markdown]
# These FIVE Models are used at a very wide scale in the Banking Industry

# %% [markdown]
# ### HANDS ON PYTHON  - CUSTOMER CHURN BANK MODEL

# %% [markdown]
# Dataset:
# https://www.kaggle.com/datasets/barelydedicated/bank-customer-churn-modeling?resource=download

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Lets  go through the Dataset :
# - It is pretty similar to what we use in the Industry
# ![image.png](attachment:9344c03c-125c-44ee-a0e3-6112b8c330b0.png)

# %% [markdown]
# This is a Dummy dataset:
# - We have fields like :
# - `Row Number` , `Customer ID`, `Customer Name (Surname)`, `CreditScore` , `Geography`, `Gender`, `Age` , `Tenure (very imp in most models)`
# - From `Tenure` , we can derive a variable called "Vintage"
# - `Vintage` is - How old the Customer is
# - Example : As the Tenure increases , the chances of Customer defaulting decreases
# - `Number of Products` : total count of different bank services or financial products
# - Example : Savings accounts, credit cards, mortgages, personal loans, or investment funds.
# - Customers with only one product or an unusually high number of products may sometimes show different
# probabilities of leaving the bank compared to those with an optimal middle range.

# %% [markdown]
# - `HasCrCard` : If the person has Credit Card or not
# - `isActiveMember:` If the person is Active or not (meaning , No transactions happening)
# - `Estimated Salary` of the person
# - We have the Label column at the End "Exited" (closed the Account or not)
# - We will first build the Model on the Actual Dataset , customers who have Exited or not Exited
# - Based on these features we will train the Model and finally when we get the New dataset , we can predict on it

# %% [markdown]
# In the Actual Datset , there are around 50 or 100 variables
# - Then the others are the Derived variables
# - Example : from "Balance" column we can derive "Balance six months ago" and many such can be derived
# - Then few variables are taken from External Data
# - Example : Cibil Score
# - A `CIBIL score` is a three-digit number from 300 to 900 that shows a person's credit history and how likely they are to repay a loan
# - Sometimes there is a secondary customer linked to the Savings Account
# - That particular customer can also have a Cibil Score
# - Then you can also Derive some Economic Factors
# - `Consumer Price Index`, The CPI measures the average change in prices paid by consumers over time and is a key measure of inflation
# - `House Price Index' , A House Price Index (HPI) is a vital statistical tool that banks and financial institutions
# use to track changes in residential property values over a specific perio
# - GDP : Gross domestic product is the monetary value of all finished goods and services made within a country during a specific period.
# GDP is the most common measure for the size of an economy
# - Again from these Macro-Economic  variables , we can derive some more variables

# %%
#Loading Data
df = pd.read_csv('Churn_Modelling.csv')

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
#Getting the List of Columns
#df.columns.values.tolist()
df_columns = list(df.columns)
print(*df_columns , sep = ' , ')
# Out:
# RowNumber , CustomerId , Surname , CreditScore , Geography , Gender , Age , Tenure , Balance , NumOfProducts , HasCrCard , IsActiveMember , EstimatedSalary , Exited

# %% [markdown]
# - RowNumber , CustomerId  are the Identification columns
# - Surname  , RowNumber , CustomerId : will not be useful
# - The model learns a profile of what a buyer looks like rather than who they are
# - Removing direct identifiers like names, phone numbers, or emails stops the model from memorizing specific people,
# but it does not stop it from learning the shared characteristics of your best buyers.

# %%
#Removing ID and Insignificant columns 
df_ML =  df.drop(columns=['RowNumber' , 'CustomerId' , 'Surname'])

# %%
df_ML.head(3)
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1

# %% [markdown]
# Geography Column would be important in situations where the Bank has Multiple Country customers
# - Meaning , it has its presence in various Geographical Locations

# %%
#Convert Categorical into Numeric Variables
#Because all the data has to be numeric when fed into the Model
#If there are 10 geographic locations , it will be converted from 0 to 9

# %%
df_ML.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
df_ML = df_ML.drop(columns = ['Geography', 'Gender'])

# %%
#(Note: Passing dtype=int forces 0 and 1 outputs instead of the default True and False booleans)
geography = pd.get_dummies(df['Geography'], dtype = int)
gender = pd.get_dummies(df['Gender'], dtype = int)

# %%
geography.head(3)
# Out:
#    France  Germany  Spain
# 0       1        0      0
# 1       0        0      1
# 2       1        0      0

# %%
gender.head(3)
# Out:
#    Female  Male
# 0       1     0
# 1       1     0
# 2       1     0

# %%
df_ML.head(3)
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1

# %%
df.head(3)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1

# %%
df_ML = pd.concat([df_ML, geography, gender] , axis = 1)

# %%
df_ML.shape
# Out:
# (10000, 14)

# %%
df_ML.columns
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'France', 'Germany',
#        'Spain', 'Female', 'Male'],
#       dtype='object')

# %%
df_ML.head(3)
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
#
#    IsActiveMember  EstimatedSalary  Exited  France  Germany  Spain  Female  \
# 0               1        101348.88       1       1        0      0       1
# 1               1        112542.58       0       0        0      1       1
# 2               0        113931.57       1       1        0      0       1
#
#    Male
# 0     0
# 1     0
# 2     0

# %% [markdown]
# Always the number of columns is n-1 when it comes to Dummy variables
# - We can even have Region , Zone etc
# - Most of the Banks have Region and Zone in their dataset
# - With , Zone we can easily identify , High Default Zone and Low Default Zone
# <b>By default, pd.get_dummies() performs full one-hot encoding instead of dummy encoding. This means it creates N features for N unique categories.  Pandas operates this way because it is designed as a general-purpose data manipulation tool rather than a strictly statistical machine learning library. Preserving all N columns retains explicit completeness for everyday tasks like data exploration, visualization, and filtering.</b>

# %% [markdown]
# #### How to enforce N-1 features
# - To drop the first category and create N-1 features (which prevents multi-collinearity
# and avoids the "dummy variable trap" in linear regressions), you must explicitly set the drop_first=True parameter

# %%
#(Note: Passing dtype=int forces 0 and 1 outputs instead of the default True and False booleans)
geography = pd.get_dummies(df['Geography'], dtype = int , drop_first=True)
gender = pd.get_dummies(df['Gender'], dtype = int, drop_first=True)

# %%
df_ML.columns
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'France', 'Germany',
#        'Spain', 'Female', 'Male'],
#       dtype='object')

# %%
#We will concatenate again
df_ML.drop(columns = ['France', 'Germany',
       'Spain', 'Female', 'Male'] , inplace = True)

# %%
df_ML.columns
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df_ML = pd.concat([df_ML, geography, gender] , axis = 1)

# %%
df_ML.head(3)
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
#
#    IsActiveMember  EstimatedSalary  Exited  Germany  Spain  Male
# 0               1        101348.88       1        0      0     0
# 1               1        112542.58       0        0      1     0
# 2               0        113931.57       1        0      0     0

# %% [markdown]
# Now we see N-1 columns

# %% [markdown]
# At this stage you can perform Data Cleaning as well
# - Check for Nulls , Duplicates

# %% [markdown]
# Additional Derived Columns in Dataset could be :
# - Average Balance in last 1 year / 6 Months /3 Months
# - Average Debit or Credit card transactions in various periods
# - Cibil Score , Zone , Region , Vintage , Quarter , Month , Year

# %% [markdown]
# Debit or Credit card transactions : In Case studies like Anti-Money Laundering , we can determine which customers
# are likely to do illegal activities . Example : A person is withdrawing Rs.10K every month, then there are sudden unusual withdrawals
# of high amounts . This raises suspicion for that account. These can be tracked from his Debit / Credit transactions
# - Again from this variable `Debit or Credit card transactions` , I can create many more variables for further Analysis

# %%
df_ML.head(2)
# Out:
#    CreditScore  Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2      0.00              1          1
# 1          608   41       1  83807.86              1          0
#
#    IsActiveMember  EstimatedSalary  Exited  Germany  Spain  Male
# 0               1        101348.88       1        0      0     0
# 1               1        112542.58       0        0      1     0

# %%
#Creating the Target Variable:
X = df_ML.drop(columns = 'Exited')
Y = df_ML['Exited']

# %% [markdown]
# We are keeping the Target / Dependant variable in Y and
# all the Independant variables in X

# %% [markdown]
# #### We are checking the Variance Inflation Factor (VIF)
# Addressing Multicollinearity in Regression Analysis
# - In regression analysis, multicollinearity occurs when independent variables are correlated with each other. This makes it difficult to determine the unique influence of each predictor on the dependent variable. As a result, you have inflated standard errors, which in turn affects the significance of coefficients.
# ![image.png](attachment:7aff36ff-d8b9-47e1-a730-5930e904b19e.png)

# %% [markdown]
# #### Interpretation of VIF Values
# Here’s how to interpret VIF values to understand the level of multicollinearity:
#
# - `**VIF = 1:**` This indicates no multicollinearity. The predictor is not correlated with other predictors, so it doesn’t inflate the standard error or affect the model’s stability.
# - `**VIF between 1 and 5:**` This suggests moderate multicollinearity. There’s some correlation with other predictors, but it’s usually not severe. However, it’s worth keeping an eye on these predictors to see if multicollinearity becomes a problem, especially if other VIF values are high.
# - `**VIF > 5:**` High multicollinearity is present. The predictor’s standard error may be noticeably inflated, which can make its coefficient less reliable. Consider taking steps to reduce multicollinearity, like removing or combining correlated predictors.
# - `**VIF > 10:**` This signals serious multicollinearity. The predictor’s standard error is highly inflated, and its coefficient estimate is likely unstable. Corrective actions, such as removing the predictor or using regularization techniques, are usually needed.

# %% [markdown]
# For instance, if a predictor’s VIF is 10, it indicates that the variance of that predictor’s coefficient is 10 times what it would be if there were no multicollinearity.

# %% [markdown]
# Multicollinearity causes standard errors to increase, which makes it harder to assess the significance of individual predictors. This happens because collinear variables carry similar information, making it difficult to separate their specific individual effects on the outcome variable.
#
# Although multicollinearity doesn’t necessarily harm the model’s ability to predict, it does reduce the reliability and clarity of the coefficients. This is especially problematic when we want to understand the individual impact of each predictor.
#
# The variance inflation factor (VIF) serves as a precise diagnostic metric to identify multicollinearity. Unlike general observations about correlation, VIF isolates the combined effect of all predictors on each variable, highlighting interactions that might not be evident from pairwise correlations.

# %% [markdown]
# https://www.datacamp.com/tutorial/variance-inflation-factor

# %% [markdown]
# So, Basically , feeding highly correlated features into a Model might not be useful for assessing the individual
# impact of a predictor . The Variables should be Independent of eachother

# %%
X.head(1)
# Out:
#    CreditScore  Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2      0.0              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0               1        101348.88        0      0     0

# %%
X.shape[1]  #There are 11 columns in X
# Out:
# 11

# %%
X.columns
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Germany', 'Spain', 'Male'],
#       dtype='object')

# %%
#High Correlation variables can be excluded
from statsmodels.stats.outliers_influence import variance_inflation_factor
#Creating empty Dataframe to store information
vif = pd.DataFrame()
#Applying vif function on X (independent variables) and storing output in new column
#vif['VIF'] = [variance_inflation_factor(X.values , i) for i in range( X.shape[1])]
vif['VIF'] = [round(variance_inflation_factor(X.values , i),2) for i in range( X.shape[1])]
#New column stores all the variable names
vif['variables'] = X.columns

# %%
vif
# Out:
#       VIF        variables
# 0   21.24      CreditScore
# 1   12.33              Age
# 2    3.87           Tenure
# 3    3.18          Balance
# 4    7.83    NumOfProducts
# 5    3.29        HasCrCard
# 6    2.08   IsActiveMember
# 7    3.89  EstimatedSalary
# 8    1.79          Germany
# 9    1.49            Spain
# 10   2.17             Male

# %% [markdown]
# VIF seems to be very high for CreditScore
# - Ideally it should not be more than 5
# - So we can remove the variables with high VIF

# %% [markdown]
# if we have lesser number of variables we can play around and keep checking which one to remove and which one should not be removed
# - But what if we have 500 or 1000 variables
# - Then comes a concept of Principal Component Analysis , which is very widely used in the Banking Industry
# - ![image.png](attachment:c2c9aa44-900e-45dc-a6f5-17091ad87dda.png)

# %% [markdown]
# #### What PCA does :
# - Suppose you have 10 variables , it creates a correlation matrix between them
# - You can easily identify highly correlated variables
# - At the backend , it is using the R square only
# ![image.png](attachment:9b636587-2d72-4d8e-bfcd-931f9dabc88e.png)

# %% [markdown]
# So, basically , clusters are formed of the variables
# - Lets say we have 50  to 55 variables, it has classified those variables into 10 clusters by using the PCA technique
# - The variables in a particular Cluster are very similar to eachother
# - We select the Top variable from every cluster , that variable will possess the highest Information value
# - Meaning the Most important variable in the group in terms of the Target variable
# - So , we have basically reduced the number of variables from 55 to just 10 or whatever
# ![image.png](attachment:45ec4d6c-c98d-49ed-a745-29ae94421208.png)

# %% [markdown]
# To get the "Information Value" , you can use the In-built functions in Python
# - We get the Information value chart like this
# ![image.png](attachment:025895b3-0982-408a-b44f-360e5228a31d.png)

# %% [markdown]
# Generally , in Banking 0.1 or higher is considered useful
# - and below that would be weak predictor and we are not using such variables at all
# - Information value combined with PCA gives you a list of Top 10-15 variables
# - Pls note : In any Industry , we generally dont prefer to have more than 10 -15 variables for a Model
# - Lets say , for my Bank Model , these are the Important variables
# ![image.png](attachment:c015a24e-d2ab-41ce-b3be-137f8b6f0dec.png)

# %% [markdown]
# So, building a Model is not only giving the forecasting , but also the Important and useful variables for the Bank
# to  flourish

# %% [markdown]
# ### Splitting into Train and Test datasets

# %% [markdown]
# - training dataset : The set of rows on which the Model is trained , Like - Ok ,these are the rows on which if this is the behaviour the Customer will default
# and these are the rows on which the customer will not default
# - test dataset : The set of Rows on which prediction is performed for testing and see what is the Actual result and then I will try to Evaluate the
# Model on the Accuracy scores etc

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train, Y_test = train_test_split(X , Y , test_size = 0.2 , random_state = 0)

# %%
X_train.shape
# Out:
# (8000, 11)

# %%
X_test.shape
# Out:
# (2000, 11)

# %%
Y_train.shape
# Out:
# (8000,)

# %%
Y_test.shape
# Out:
# (2000,)

# %%
type(Y_test)
# Out:
# pandas.core.series.Series

# %%
X_test.head(2)
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 9394          597   35       8  131101.04              1          1
# 898           523   40       2  102967.41              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 9394               1        192852.67        1      0     0
# 898                0        128702.10        0      0     0

# %%
Y_test.head(3)
# Out:
# 9394    0
# 898     1
# 2398    0
# Name: Exited, dtype: int64

# %% [markdown]
# ### Model Building

# %% [markdown]
# We try different Models
# - A good machine learning model is a well-optimized system that generalizes
# accurately to new, unseen data while remaining efficient, robust, and interpretable
# #### Core PropertiesGeneralization:
# - The model performs well on data it has never seen before, avoiding the trap of memorizing training data.
# - `High Performance:` It scores well on key testing metrics like accuracy, precision, recall, or F1 score depending on the specific problem.
# - `Interpretability:` People can understand how the model makes its choices, which builds trust and safety.
# - `Robustness:` The model handles messy data, missing values, and unusual data points (outliers) without failing.
# - `Efficiency:` It uses a reasonable amount of computer memory and time to train and make predictions.
# - `Simplicity:` It follows the simplest path that works, making it easier to maintain and debug

# %%
#Machine Learning Algorithm Training
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 200 , random_state = 0)
classifier.fit(X_train , Y_train)
predictions = classifier.predict(X_test)

# %%
#Machine Learning Algorithm Evaluation
from sklearn.metrics import classification_report , accuracy_score
print(classification_report(Y_test, predictions))
print(accuracy_score(Y_test , predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      1595
#            1       0.73      0.51      0.60       405
#
#     accuracy                           0.86      2000
#    macro avg       0.81      0.73      0.76      2000
# weighted avg       0.85      0.86      0.85      2000
#
# 0.8635

# %% [markdown]
# - I Got the Final Accuracy of 86% which is very good
# - Anything above 70% is accepted in the Banking industry
# - If its more than 90% means , your data is Overtrained or overskewed
# - Such a Model will not generalize in real world

# %%
Y_test.shape
# Out:
# (2000,)

# %%
predictions.shape
# Out:
# (2000,)

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

cm = confusion_matrix(Y_test, predictions, labels=classifier.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=classifier.classes_)
disp.plot()
plt.show()

# %% [markdown]
# - 1519 : True Negative
# - 76 : False Positive
# - 197 : False Negative
# - 208 : True Positive

# %% [markdown]
# ### We will try XG Boost

# %% [markdown]
# XG Boost gives better Accuracy 95% of the times

# %%
# !pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/48.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/48.9 MB ? eta -:--:--
#    ---------------------------------------- 0.5/48.9 MB 1.8 MB/s eta 0:00:27
#    - -------------------------------------- 2.4/48.9 MB 5.6 MB/s eta 0:00:09
#    ------ --------------------------------- 7.6/48.9 MB 12.5 MB/s eta 0:00:04
#    -------------- ------------------------- 18.1/48.9 MB 22.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 28.8/48.9 MB 27.8 MB/s eta 0:00:01
#    ------------------------ --------------- 30.4/48.9 MB 28.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 35.7/48.9 MB 24.4 MB/s eta 0:00:01
#    -------------------------------- ------- 40.1/48.9 MB 24.3 MB/s eta 0:00:01
#    ------------------------------------- -- 45.6/48.9 MB 25.0 MB/s eta 0:00:01
#    ---------------------------------------  48.8/48.9 MB 23.7 MB/s eta 0:00:01
# ...

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(X_train , Y_train)
predictions = model.predict(X_test)
print(classification_report(Y_test , predictions))
print(accuracy_score(Y_test , predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      1595
#            1       0.67      0.52      0.59       405
#
#     accuracy                           0.85      2000
#    macro avg       0.78      0.73      0.75      2000
# weighted avg       0.84      0.85      0.84      2000
#
# 0.8515

# %% [markdown]
# The Accuracy is lower than the above Model
# - we can go with the previous Model
# - Because , the more simpler the Model is , the more easier is to explain to the business
# - You only go to the complex algorithms when your generic algorithm is not working

# %% [markdown]
# We predicted on the test data
# - So, once your Model is ready
# - Whenever new data comes , we can feed that data into this Model
# - Suppose you feed 1 Lakh customer data
# - We get a result of 5000 are likely to churn
# - So the Bank can Target those specific 5000 Customers and try to retain those Customers

# %% [markdown]
# #### Predictions

# %% [markdown]
# - Usually the Predictions are done for the next Quarter or on a Monthly basis also
# - We usually have to run the Model when we are having the Quarter End
# - Example ,we will have the data till 31st of Dec  >>>> We ran the Model in Jan >>>> Bank will be implementing it by 1st of Feb
# - So, that means , the predictions that are made in JAN , we will get the 5000 customers (out of 1 lakh) who are likely to default
# - So,thebank will target these customers in the next three months (Feb , March , Apr)
# - That they dont churn out or leave the bank
# - It is totally up to the business , what months the will choose

# %% [markdown]
# ### Scoring the Model

# %% [markdown]
# When you run the Model on an Unseen data , it is called Scoring the Model
# - Model Building is done only once
# - Then this Model can be used for 3-5 years in the Banking industry
# - Yoi can get good information from the model which you can use for the next 3 - 5 yrs
# - If new variables are introduced then you need to Re-tune the Model by adding those variables

# %% [markdown]
# ### Feature Importance  OR Feature Evaluation

# %% [markdown]
# - How important a particular variable is

# %%
feat_importances = pd.Series(classifier.feature_importances_ , index = X.columns)
feat_importances.nlargest(10).plot(kind = 'barh')
# Out:
# <Axes: >

# %% [markdown]
# - Age is very important (check the length of the bar)
# - CreditScore is less important and it having a high VIF score , we can drop this variable as well
# - Number of Products are also very important, one who holds more products is less likely to default
# - We can addan important variable to our dataset - "Scheme"
# - laa : term loan ,,, tda : term deposit , sba : Savings balance account
# - So , rather than having 86% Accuracy with 12 variables , its preferred to have an accurac of 84% or even 81% with 5 variables
# - Because you can easily tell the business , these are the 5 variables that are contributing
# - Precision and Recall also need to be compared , All three Accuracy , Precision and Recall should be more than 60%

# %% [markdown]
# =============================================================================================================
